# %%
from random import randint
import numpy as np
import cv2
import matplotlib.pyplot as plt
import imageio

# %%
image = cv2.imread('input/village-scaled.jpg')

# %%
row , col , _= image.shape
snow_list = []

for i in range(400):
    random_x = randint(0,row)
    random_y = randint(0,col)
    random_radius = randint(2,3)
    # for j in range(0,200,50):
    snow = cv2.circle(image,(random_y,random_x+j) ,random_radius, (255, 255, 255),-1)
        # snow_list.append(snow)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
cv2.imwrite('output/img.jpg',image)

# imageio.mimsave('output/video.gif',snow_list, fps=60)
# Out:
# True
